# %% [markdown]
# # Diabetes Risk Prediction — Model Interpretation with SHAP
#
# **Goal:** Explain what drives the final XGBoost model's predictions, both globally
# (across the whole dataset) and for individual patients.
#
# Sections:
# 1. Recreate data split and retrain final model
# 2. Compute SHAP values
# 3. Global feature importance (summary plot)
# 4. Feature effect direction (beeswarm plot)
# 5. Individual prediction explanation (waterfall plot)
# 6. Dependence plots for top features
# 7. Key takeaways

# %%
pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.52.0-cp312-abi3-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: numpy>=2 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (2.4.6)
# Requirement already satisfied: scipy in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (1.18.0)
# Requirement already satisfied: scikit-learn in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (1.9.0)
# Requirement already satisfied: pandas in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (3.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (4.68.2)
# Requirement already satisfied: packaging>20.9 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (26.0)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (0.65.1)
# Requirement already satisfied: llvmlite in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (0.47.0)
# Requirement already satisfied: cloudpickle in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: colorama in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from pandas->shap) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from scikit-learn->shap) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\14697\Downloads\anaconda\Lib\site-packages (from scikit-learn->shap) (3.5.0)
# Downloading shap-0.52.0-cp312-abi3-win_amd64.whl (499 kB)
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# Successfully installed shap-0.52.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap

from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

RANDOM_STATE = 42
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={543(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",l="__lodash_placeholder__",u=32,s=128,c=1/0,f=9007199254740991,d=NaN,p=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",u],["partialRight",64],["rearg",256]],g="[object Arguments]",v="[object Array]",m="[object Boolean]",y="[object Date]",b="[object Error]",w="[object Function]",_="[object GeneratorFunction]",k="[object Map]",x="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",P="[object Set]",T="[object String]",O="[object Symbol]",z="[object WeakMap]",N="[object ArrayBuffer]",M="[object DataView]",A="[object Float32Array]",L="[object Float64Array]",j="[object Int8Array]",F="[object Int16Array]",D="[object Int32Array]",R="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,H=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,W=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(W.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,X=/<%=([\s\S]+?)%>/g,Z=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,le=/,? & /,ue=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,de=/\w*$/,pe=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ge=/^\[object .+?Constructor\]$/,ve=/^0o[0-7]+$/i,me=/^(?:0|[1-9]\d*)$/,ye=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,we=/['\n\r\u2028\u2029\\]/g,_e="\\ud800-\\udfff",ke="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",xe="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Pe="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Te="["+_e+"]",Oe="["+Pe+"]",ze="["+ke+"]",Ne="\\d+",Me="["+xe+"]",Ae="["+Se+"]",Le="[^"+_e+Pe+Ne+xe+Se+Ee+"]",je="\\ud83c[\\udffb-\\udfff]",Fe="[^"+_e+"]",De="(?:\\ud83c[\\udde6-\\uddff]){2}",Re="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Ae+"|"+Le+")",Be="(?:"+Ue+"|"+Le+")",He="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",We="(?:"+ze+"|"+je+")?",qe="["+Ce+"]?",Qe=qe+We+"(?:"+Ie+"(?:"+[Fe,De,Re].join("|")+")"+qe+We+")*",Ye="(?:"+[Me,De,Re].join("|")+")"+Qe,Ge="(?:"+[Fe+ze+"?",ze,De,Re,Te].join("|")+")",Ke=RegExp("['’]","g"),Xe=RegExp(ze,"g"),Ze=RegExp(je+"(?="+je+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Ae+"+"+He+"(?="+[Oe,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Oe,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+He,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",Ne,Ye].join("|"),"g"),et=RegExp("["+Ie+_e+ke+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[A]=at[L]=at[j]=at[F]=at[D]=at[R]=at[U]=at[I]=at[$]=!0,at[g]=at[v]=at[N]=at[m]=at[M]=at[y]=at[b]=at[w]=at[k]=at[x]=at[S]=at[C]=at[P]=at[T]=at[z]=!1;var it={};it[g]=it[v]=it[N]=it[M]=it[m]=it[y]=it[A]=it[L]=it[j]=it[F]=it[D]=it[k]=it[x]=it[S]=it[C]=it[P]=it[T]=it[O]=it[R]=it[U]=it[I]=it[$]=!0,it[b]=it[w]=it[z]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},lt=parseFloat,ut=parseInt,st="object"==typeof n ...

# %% [markdown]
# ## 1. Recreate Data Split & Retrain Final Model
#
# Same split as notebooks 02/03, so this analysis lines up with your reported results.
# If you saved the model in notebook 03 (`joblib.dump`), you can load it instead of retraining.

# %%
from ucimlrepo import fetch_ucirepo

cdc_diabetes = fetch_ucirepo(id=891)
X_raw = cdc_diabetes.data.features
y_raw = cdc_diabetes.data.targets

df = pd.concat([X_raw, y_raw], axis=1)
df = df.drop_duplicates().reset_index(drop=True)

target_col = 'Diabetes_binary'
X = df.drop(columns=[target_col])
y = df[target_col]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
)

scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    scale_pos_weight=scale_pos_weight,
    eval_metric='logloss',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
xgb_model.fit(X_train, y_train)

print('Model retrained. Test shape:', X_test.shape)
# Out:
# Model retrained. Test shape: (45895, 21)

# %% [markdown]
# ## 2. Compute SHAP Values
#
# `TreeExplainer` is fast and exact for tree-based models like XGBoost. We use a sample of
# the test set for the summary/beeswarm plots to keep things quick — SHAP computation scales
# with dataset size.

# %%
# Sample for speed — increase sample_size if you want more precision and have time to spare
sample_size = 15000
X_sample = X_test.sample(n=min(sample_size, len(X_test)), random_state=RANDOM_STATE)

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer(X_sample)

print('SHAP values shape:', shap_values.values.shape)
# Out:
# SHAP values shape: (15000, 21)

# %% [markdown]
# ## 3. Global Feature Importance
#
# This bar plot ranks features by their average impact on model output (magnitude only,
# no direction). This is the plot to screenshot for a quick 'what matters most' summary.

# %%
shap.plots.bar(shap_values, max_display=15)

# %% [markdown]
# ## 4. Feature Effect Direction (Beeswarm Plot)
#
# This shows not just which features matter, but HOW — e.g. does high BMI push predictions
# toward higher risk (positive SHAP value) or lower risk? Each dot is one patient in the sample;
# color shows the feature's value (red = high, blue = low).

# %%
shap.plots.beeswarm(shap_values, max_display=15)

# %% [markdown]
# ## 5. Individual Prediction Explanation (Waterfall Plot)
#
# This explains a single prediction — useful for showing 'here's why the model flagged this
# specific person as high-risk.' Great for a portfolio screenshot showing real-world applicability.

# %%
# Pick an example the model is confident is high-risk
probs = xgb_model.predict_proba(X_sample)[:, 1]
high_risk_idx = np.argmax(probs)

print(f'Predicted probability of diabetes/prediabetes: {probs[high_risk_idx]:.3f}')
shap.plots.waterfall(shap_values[high_risk_idx], max_display=15)
# Out:
# Predicted probability of diabetes/prediabetes: 0.975

# %%
# And a low-risk example for contrast
low_risk_idx = np.argmin(probs)

print(f'Predicted probability of diabetes/prediabetes: {probs[low_risk_idx]:.3f}')
shap.plots.waterfall(shap_values[low_risk_idx], max_display=15)
# Out:
# Predicted probability of diabetes/prediabetes: 0.000

# %% [markdown]
# ## 6. Dependence Plots for Top Features
#
# Shows how a single feature's value relates to its SHAP impact, and whether it interacts
# with another feature (shown via color).

# %%
# Update this list based on what showed up as top features in the plots above
top_features = ['BMI', 'GenHlth', 'Age', 'HighBP']
top_features = [f for f in top_features if f in X_sample.columns]

for feature in top_features:
    shap.plots.scatter(shap_values[:, feature], color=shap_values)
    plt.show()
